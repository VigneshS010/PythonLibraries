# %% [markdown]
# # Loading data into the Pandas

# %%
import pandas as pd

# Load data into pandas

# dataframe
# csv file
df = pd.read_csv('Pokemon.csv')

# xlsx file
# df_xlsx = pd.read_excel('data.xlsx')

# txt file
# df_txt = pd.read_csv('data.txt', delimiter='\t')

print(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Get Specific Top or bottom Rows of data
print(df.head(5))

#For bottom tail is used
#print(df.tail(3))
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Reading Data in Pandas

# %%
## Read Headers

print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## Reading each Columns

print(df['Name'][0:3]) # Required set of data

print()
print(df[['Name','Speed','HP']][0:3])
#print(df.Name)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object
#
#         Name  Speed  HP
# 0  Bulbasaur     45  45
# 1    Ivysaur     60  60
# 2   Venusaur     80  80

# %%
## Reading Each Row

# print(df.head(3))
print(df.iloc[0:4])

# Itterating through the Data using for loop
# for index, row in df.iterrows():
#   print(index,row['Name'])
#   print(index,row)


# Printing the specific Type pokemon
# print(df.loc[df['Type 1'] == 'Fire'])
print(df.loc[df['Type 2'] == 'Grass'])
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
#        #                   Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 51    46                  Paras       Bug  Grass    285   35      70       55
# 52    47               Parasect       Bug  Grass    405   60      95       80
# 271  251                 Celebi   Psychic  Grass    600  100     100      100
# ...

# %%
## Reading the specific Location (R, C)

print(df.iloc[2,1])
# Out:
# Venusaur

# %% [markdown]
# # Sorting / Describing Data

# %%
# Get mean median etc for the int values in the Dataset
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# Print by reverse alphabetic
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['HP','Attack'], ascending = [False, True])
# Out:
#        #       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey    Normal    NaN    540  255      10       10       75
# 121  113    Chansey    Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet   Psychic    NaN    405  190      33       58       33
# 351  321    Wailord     Water    NaN    500  170      90       45       90
# 655  594  Alomomola     Water    NaN    470  165      75       80       40
# ..   ...        ...       ...    ...    ...  ...     ...      ...      ...
# 487  439   Mime Jr.   Psychic  Fairy    310   20      25       45       70
# 186  172      Pichu  Electric    NaN    205   20      40       15       35
# 388  355    Duskull     Ghost    NaN    295   20      40       90       30
# 55    50    Diglett    Ground    NaN    265   10      55       25       35
# 316  292   Shedinja       Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the Data

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense']
df['Total'] = df.iloc[:, 4:10].sum(axis = 1)

# %%
#df[['Attack','HP','Defense','Total']][0:5]
df.iloc[4:10][0:5]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    553  39      52       43
# 5  5                 Charmeleon   Fire     NaN    730  58      64       58
# 6  6                  Charizard   Fire  Flying    968  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon   1168  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying   1168  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
# Drop a column

df = df.drop(columns = ['HP'])
df[0:5]
# Out:
#    #                   Name Type 1  Type 2  Total  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison    591      49       49       65
# 1  2                Ivysaur  Grass  Poison    750      62       63       80
# 2  3               Venusaur  Grass  Poison    970      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison   1170     100      123      122
# 4  4             Charmander   Fire     NaN    553      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Switching place of Total to front

cols = list(df.columns)

df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Legendary  Legendary  \
# 0  1              Bulbasaur  Grass  Poison      False      False      False
# 1  2                Ivysaur  Grass  Poison      False      False      False
# 2  3               Venusaur  Grass  Poison      False      False      False
# 3  3  VenusaurMega Venusaur  Grass  Poison      False      False      False
# 4  4             Charmander   Fire     NaN      False      False      False
#
#    Legendary  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      False    591      49       49       65       65     45           1
# 1      False    750      62       63       80       80     60           1
# 2      False    970      82       83      100      100     80           1
# 3      False   1170     100      123      122      120     80           1
# 4      False    553      52       43       60       50     65           1

# %% [markdown]
# # Saving our Data(Exporting into Desired Format)

# %%
# Saving the data into csv format

df.to_csv('modified.csv', index = False)

# to excel

df.to_excel('modiefied.xlsx', index = False)

# to txt

df.to_csv('modified.txt',index = False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
#df.loc[df['Type 1'] == 'Grass'][0:4]

# Grass + Poison Pokemons
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['Total']  > 750)]
# We can store the  data into a variable name as newdf
# And save into a diff csv file

new_df.to_csv('new.csv')
# new_df.to_excel('new.xlsx')
# new_df.to_csv('new.txt', index = False, sep = '\t')

#To reset the index in the new filtered data
new_df = new_df.reset_index(drop = True)
print(new_df)
# Out:
#      #                   Name Type 1  Type 2  Legendary  Legendary  Legendary  \
# 0    3               Venusaur  Grass  Poison      False      False      False
# 1    3  VenusaurMega Venusaur  Grass  Poison      False      False      False
# 2   45              Vileplume  Grass  Poison      False      False      False
# 3   71             Victreebel  Grass  Poison      False      False      False
# 4  407               Roserade  Grass  Poison      False      False      False
# 5  591              Amoonguss  Grass  Poison      False      False      False
#
#    Legendary  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      False    970      82       83      100      100     80           1
# 1      False   1170     100      123      122      120     80           1
# 2      False    930      80       85      110       90     50           1
# 3      False    910     105       65      100       70     70           1
# ...

# %%
# Filtering Mega  Pokemons

mega_poke = df.loc[df['Name'].str.contains('Mega') ]
# mega_poke = df.loc[~df['Name'].str.contains('Mega') ] ##This extra kw removes the condition
mega_poke.reset_index(drop=True)
mega_poke[0:5]
# Out:
#    #        Name Type 1  Type 2  Legendary  Legendary  Legendary  Legendary  \
# 0  1   Bulbasaur  Grass  Poison      False      False      False      False
# 1  2     Ivysaur  Grass  Poison      False      False      False      False
# 2  3    Venusaur  Grass  Poison      False      False      False      False
# 4  4  Charmander   Fire     NaN      False      False      False      False
# 5  5  Charmeleon   Fire     NaN      False      False      False      False
#
#    Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    591      49       49       65       65     45           1
# 1    750      62       63       80       80     60           1
# 2    970      82       83      100      100     80           1
# 4    553      52       43       60       50     65           1
# 5    730      64       58       80       65     80           1

# %% [markdown]
# Regex Filtering

# %%
 import re

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]

# To ignore case sensitive
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I ,regex=True)]

# get pokemons name start with pi
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I ,regex=True)]
# pi only at starting
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I ,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Legendary  \
# 20    16               Pidgey    Normal    Flying      False      False
# 21    17            Pidgeotto    Normal    Flying      False      False
# 22    18              Pidgeot    Normal    Flying      False      False
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False      False
# 30    25              Pikachu  Electric       NaN      False      False
# 136  127               Pinsir       Bug       NaN      False      False
# 137  127    PinsirMega Pinsir       Bug    Flying      False      False
# 186  172                Pichu  Electric       NaN      False      False
# 219  204               Pineco       Bug       NaN      False      False
# 239  221            Piloswine       Ice    Ground      False      False
# 438  393               Piplup     Water       NaN      False      False
# 558  499              Pignite      Fire  Fighting      False      False
# ...

# %% [markdown]
# # Condition Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df[0:5]
# Out:
#    #                   Name Type 1  Type 2  Legendary  Legendary  Legendary  \
# 0  1              Bulbasaur  Grass  Poison      False      False      False
# 1  2                Ivysaur  Grass  Poison      False      False      False
# 2  3               Venusaur  Grass  Poison      False      False      False
# 3  3  VenusaurMega Venusaur  Grass  Poison      False      False      False
# 4  4             Charmander   Fire     NaN      False      False      False
#
#    Legendary  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      False    591      49       49       65       65     45           1
# 1      False    750      62       63       80       80     60           1
# 2      False    970      82       83      100      100     80           1
# 3      False   1170     100      123      122      120     80           1
# 4      False    553      52       43       60       50     65           1

# %%
# Making all Fire pokemon as Legendary
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df[0:5]
# Out:
#    #                   Name Type 1  Type 2  Legendary  Legendary  Legendary  \
# 0  1              Bulbasaur  Grass  Poison      False      False      False
# 1  2                Ivysaur  Grass  Poison      False      False      False
# 2  3               Venusaur  Grass  Poison      False      False      False
# 3  3  VenusaurMega Venusaur  Grass  Poison      False      False      False
# 4  4             Charmander   Fire     NaN       True       True       True
#
#    Legendary  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      False    591      49       49       65       65     45           1
# 1      False    750      62       63       80       80     60           1
# 2      False    970      82       83      100      100     80           1
# 3      False   1170     100      123      122      120     80           1
# 4       True    553      52       43       60       50     65           1

# %%
df = pd.read_csv('modified.csv')  # Reloding the original dataframe

# %%
# Checking and changing the df

df.loc[df['Total'] > 800 , ['Generation', 'Legendart']] = ['TEST VALUE','Test2']
df[0:5]
# Out:
#    #                   Name Type 1  Type 2  Legendary  Legendary.1  \
# 0  1              Bulbasaur  Grass  Poison      False        False
# 1  2                Ivysaur  Grass  Poison      False        False
# 2  3               Venusaur  Grass  Poison      False        False
# 3  3  VenusaurMega Venusaur  Grass  Poison      False        False
# 4  4             Charmander   Fire     NaN      False        False
#
#    Legendary.2  Legendary.3  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0        False        False    591      49       49       65       65     45
# 1        False        False    750      62       63       80       80     60
# 2        False        False    970      82       83      100      100     80
# 3        False        False   1170     100      123      122      120     80
# 4        False        False    553      52       43       60       50     65
#
#    Generation Legendart
# 0           1       NaN
# 1           1       NaN
# ...

# %% [markdown]
# # Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')  # Reloding the original dataframe

# %%
# df.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)

# %%
df.groupby(['Type 1']).sum()

df['count'] = 1
df.groupby(['Type 1']).count()['count']
# df.groupby(['Type 1', 'Type 2']).count()['count']

#df.groupby(['Type 1']).count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %% [markdown]
# # Working with Large amount of Data

# %%
new_df =  pd.DataFrame(columns = df.columns)
for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()

    new_df = pd.concat([new_df, results])
    # print('CHUNK DF')
    # print(df)

new_df.to_csv('mod.csv')
